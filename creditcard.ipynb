# %% [markdown]
# <a href="https://colab.research.google.com/github/shrush7/CODSOFT/blob/main/creditcard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
file=pd.read_csv("creditcard.csv")

# %%
file.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
file.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  170463.000000  170463.000000  170463.000000  170463.000000
# mean    60945.692185      -0.171418       0.041438       0.496009
# std     27706.565970       1.850499       1.611466       1.382129
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     41172.500000      -0.987177      -0.538322      -0.061200
# 50%     60665.000000      -0.185295       0.110233       0.625232
# 75%     78493.000000       1.183845       0.804500       1.298406
# max    120194.000000       2.439207      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  170463.000000  170463.000000  170463.000000  170463.000000
# mean        0.118163      -0.177346       0.058682      -0.081195
# std         1.371813       1.338482       1.295161       1.208874
# min        -5.519697     -42.147898     -26.160506     -43.557242
# ...

# %%
file.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
file['Class'].value_counts()
# Out:
# 0.0    170102
# 1.0       360
# Name: Class, dtype: int64

# %%
normal=file[file.Class==0]

# %%
fraud=file[file.Class==1]

# %%
print(normal.shape)
# Out:
# (170102, 31)

# %%
print(normal.shape)
# Out:
# (170102, 31)

# %%
normal.Amount.describe()
# Out:
# count    170102.000000
# mean         87.272509
# std         246.067820
# min           0.000000
# 25%           5.490000
# 50%          21.890000
# 75%          76.500000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     360.000000
# mean      111.576722
# std       227.309252
# min         0.000000
# 25%         1.000000
# 50%        11.385000
# 75%       104.007500
# max      1809.680000
# Name: Amount, dtype: float64

# %%
file.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    60954.436285 -0.159027  0.032193  0.513948  0.108071 -0.168484
# 1.0    56649.477778 -6.026758  4.406926 -7.976571  4.889177 -4.367960
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.061850 -0.066521  0.031054  0.025195  ...  0.030372 -0.030393
# 1.0   -1.436827 -7.017053  0.745264 -2.863575  ...  0.405161  0.793171
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.084402 -0.022560  0.009386  0.092777  0.012642  0.001681  0.002371
# 1.0   -0.025930 -0.037556 -0.073778  0.080099  0.038996  0.182902  0.052482
#
#            Amount
# Class
# 0.0     87.272509
# 1.0    111.576722
#
# [2 rows x 30 columns]

# %%
normal_sample=normal.sample(n=492)

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 37244    38873.0  1.322214 -0.475700 -0.061405 -0.557010 -0.727496 -0.571201
# 67214    52416.0  1.039506  0.709224  1.213372  4.021614 -0.322588 -0.243899
# 57185    47797.0  0.616279 -2.382324 -0.858172 -0.913534  0.519216  4.318120
# 114378   73457.0 -3.305218 -7.172688 -2.813947  3.029481 -1.814998  0.957197
# 156557  108378.0  1.761681 -0.134578  1.540911  4.500133 -1.041117  1.404105
# 57648    47996.0  1.015015 -0.587048  1.183766  0.330738 -1.214901 -0.079118
# 82204    59297.0  0.964766 -0.670080  1.154601  0.351866 -1.240553 -0.069758
# 122445   76563.0 -1.529448  0.480482  1.469545 -1.877185 -0.867318 -0.771611
# 3626      3102.0 -0.912541  0.926385  1.894614  0.552219  0.097420 -0.165988
# 7089      9289.0  1.151700 -0.011932  1.170528  1.134889 -0.707808 -0.002691
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
new_file['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    360
# Name: Class, dtype: int64

# %%
new_file.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    60537.355691 -0.242422  0.093280  0.418368  0.235225 -0.230063
# 1.0    56649.477778 -6.026758  4.406926 -7.976571  4.889177 -4.367960
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.145884  0.034412  0.048495  0.040544  ...  0.009769  0.014184
# 1.0   -1.436827 -7.017053  0.745264 -2.863575  ...  0.405161  0.793171
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.065786 -0.000453  0.048042  0.053295  0.005964  0.024439 -0.014432
# 1.0   -0.025930 -0.037556 -0.073778  0.080099  0.038996  0.182902  0.052482
#
#            Amount
# Class
# 0.0    100.230955
# 1.0    111.576722
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,Y_train)*100

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 94.86049926578562%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)*100

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 92.39766081871345%
